# %% [markdown]
# # 🍄 Mushroom Proportions

# %%
import pandas as pd
import matplotlib.pyplot as plt
mushrooms = pd.read_csv('../../data/mushrooms.csv')
mushrooms.head()
# Out:
#        class cap-shape cap-surface cap-color     bruises     odor  \
# 0  Poisonous    Convex      Smooth     Brown     Bruises  Pungent
# 1     Edible    Convex      Smooth    Yellow     Bruises   Almond
# 2     Edible      Bell      Smooth     White     Bruises    Anise
# 3  Poisonous    Convex       Scaly     White     Bruises  Pungent
# 4     Edible    Convex      Smooth     Green  No Bruises      NaN
#
#   gill-attachment gill-spacing gill-size gill-color  ...  \
# 0            Free        Close    Narrow      Black  ...
# 1            Free        Close     Broad      Black  ...
# 2            Free        Close     Broad      Brown  ...
# 3            Free        Close    Narrow      Brown  ...
# 4            Free      Crowded     Broad      Black  ...
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                   Smooth                  White                  White
# 1                   Smooth                  White                  White
# 2                   Smooth                  White                  White
# 3                   Smooth                  White                  White
# 4                   Smooth                  White                  White
#
#   veil-type veil-color ring-number   ring-type spore-print-color population  \
# 0   Partial      White         One     Pendant             Black  Scattered
# 1   Partial      White         One     Pendant             Brown   Numerous
# 2   Partial      White         One     Pendant             Brown   Numerous
# 3   Partial      White         One     Pendant             Black  Scattered
# 4   Partial      White         One  Evanescent             Brown   Abundant
#
#    habitat
# 0    Urban
# 1  Grasses
# 2  Meadows
# 3    Urban
# 4  Grasses
#
# [5 rows x 23 columns]

# %%
print(mushrooms.columns)
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
class_mushrooms = mushrooms.groupby('class').count()
class_mushrooms
# Out:
#            cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# class
# Edible          4208         4208       4208     4208   800             4208
# Poisonous       3916         3916       3916     3916  3796             3916
#
#            gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# class                                                        ...
# Edible             4208       4208        4208         4208  ...
# Poisonous          3916       3916        3916         3916  ...
#
#            stalk-surface-below-ring  stalk-color-above-ring  \
# class
# Edible                         4208                    4208
# Poisonous                      3916                    3916
#
#            stalk-color-below-ring  veil-type  veil-color  ring-number  \
# class
# Edible                       4208       4208        4208         4208
# Poisonous                    3916       3916        3916         3880
#
#            ring-type  spore-print-color  population  habitat
# class
# Edible          4208               4208        4208     4208
# Poisonous       3880               3916        3916     3916
#
# [2 rows x 22 columns]

# %%
plt.pie(class_mushrooms['population'], labels = ['Edible','Poisonous'], autopct='%.1f %%')

plt.show()

# %%
habitat = mushrooms.groupby(['habitat']).count()


labels=['Grasses','Leaves','Meadows','Paths','Urban','Waste','Wood']

plt.pie(habitat['class'], labels=labels,
        autopct='%1.1f%%', pctdistance=0.85)
  
center_circle = plt.Circle((0, 0), 0.40, fc='white')
fig = plt.gcf()

fig.gca().add_artist(center_circle)
  
plt.title('Mushroom Habitats')
  
plt.show()

# %%
pip install pywaffle
# Out:
# Collecting pywaffle
#   Downloading pywaffle-1.1.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting fontawesomefree (from pywaffle)
#   Downloading fontawesomefree-6.6.0-py3-none-any.whl.metadata (853 bytes)
# Requirement already satisfied: matplotlib in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from pywaffle) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from matplotlib->pywaffle) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ia0070483\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.17.0)
# Downloading pywaffle-1.1.1-py2.py3-none-any.whl (30 kB)
# Downloading fontawesomefree-6.6.0-py3-none-any.whl (25.6 MB)
#    ---------------------------------------- 0.0/25.6 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/25.6 MB 11.4 MB/s eta 0:00:03
#    ------ --------------------------------- 4.5/25.6 MB 11.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.8/25.6 MB 11.5 MB/s eta 0:00:02
#    ------------- -------------------------- 8.9/25.6 MB 11.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 11.5/25.6 MB 11.4 MB/s eta 0:00:02
#    --------------------- ------------------ 13.6/25.6 MB 11.4 MB/s eta 0:00:02
#    ------------------------ --------------- 16.0/25.6 MB 11.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.4/25.6 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 20.7/25.6 MB 11.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.1/25.6 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  25.2/25.6 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 25.6/25.6 MB 10.9 MB/s eta 0:00:00
# Installing collected packages: fontawesomefree, pywaffle
#
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 0/2 [fontawesomefree]
#    ---------------------------------------- 2/2 [pywaffle]
#
# Successfully installed fontawesomefree-6.6.0 pywaffle-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pywaffle import Waffle

capcolor=mushrooms.groupby(['cap-color']).count()

data ={'color': ['brown', 'buff', 'cinnamon', 'green', 'pink', 'purple', 'red', 'white', 'yellow'],
    'amount': capcolor['class']
     }
  
df = pd.DataFrame(data)
  
fig = plt.figure(
    FigureClass = Waffle,
    rows = 100,
    values = df.amount,
    labels = list(df.color),
    figsize = (30,30),
    colors=["brown", "tan", "maroon", "green", "pink", "purple", "red", "whitesmoke", "yellow"],
)
# Out:
# <Waffle size 3000x3000 with 1 Axes>
